# %% [markdown]
# # 課題01

# %% [markdown]
# 【学籍番号】1254810976
#
# 【氏　　名】坂本快

# %% [markdown]
# ## Q01
#
# 次のプログラムには誤りがある。誤りを修正し
#
# ```Hello World!```
#
# と表示するプログラムにせよ。

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# ## Q02
#
# 次のプログラムには誤りがある。誤りを修正し
#
# ```Welcome to python!```
#
# と表示するプログラムにせよ。

# %%
print('Welcome to python!')
# Out:
# Welcome to python!
